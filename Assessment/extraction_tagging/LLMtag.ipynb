# %%
import numpy as np
import pandas as pd
import re
import json
import time
from google import genai
from google.genai.types import GenerateContentConfig

from journal_config import *

# %%
l_journal = list(JOURNAL_DOI.keys())

# %%
client = genai.Client(api_key=GEMINI_API_KEY)

# %% [markdown]
# Check max tokens for LLM input

# %%
model_info = client.models.get(model="gemini-2.5-flash")
print(f"{model_info.input_token_limit=}")
print(f"{model_info.output_token_limit=}")
# Out:
# model_info.input_token_limit=1048576
# model_info.output_token_limit=65536

# %% [markdown]
# Check token size for query:
# For Gemini models, a token is equivalent to about 4 characters. 100 tokens is equal to about 60-80 English words.
# https://ai.google.dev/gemini-api/docs/tokens?lang=python

# %%
total_tokens = client.models.count_tokens(
    model="gemini-2.5-flash-lite", 
    contents=
    """
    from the following 100 rows, extract in a sentence length: the paper_title, background, research question, data and methods, main results, implications, whether it is AI related; for each row in JSON format.
    """
    +
    str(df[0:50])
)
print("total_tokens: ", total_tokens)
# Out:
# total_tokens:  sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) total_tokens=2752 cached_content_token_count=None

# %% [markdown]
# ### AI tagging

# %%
batch_size = 50

for j in d_journal_doi.keys():
    df = pd.read_csv(j+'.csv')
    df = df[~df['abstract'].isna()]
    df = df[['title', 'author', 'publication_year', 'journal_name', 'abstract']]
    df_response = pd.DataFrame()
    
    for i in range(0, len(df), batch_size):
        print("batch"+str(i))
        while True:
            try:
                response = client.models.generate_content(
                    model='gemini-2.5-flash-lite',
                    config=GenerateContentConfig(
                        system_instruction="Always respond *only* in valid JSON without extra commentary.", 
                        temperature=0.2
                    ),
                    contents=
                    f"""
                    from the following {batch_size} rows, extract: the background, research_question, data, methods, main_results, implications, whether it is_AI_related, AI_related_keyword if is_AI_related is True; keep original columns ['title', 'publication_year', 'journal_name'] as identifiers in the output; do this for each row and output only JSON format.
                    """
                    +
                    str(df[i:i+batch_size])
                )
                df_json = pd.read_json(re.sub(r"^```json\s*|\s*```$", "", response.text, flags=re.DOTALL))
                df_response = pd.concat([df_response, df_json], ignore_index=True)
                print(len(df_json))
                time.sleep(300)
                break
            except Exception as e:
                print("batch"+str(i)+" re-attempt")
                time.sleep(100)
        for e in df_response.title:
            print(e)
    df_response.to_csv(j+'_response.csv', index=False)
# Out:
# batch0
# C:\Users\Lab\AppData\Local\Temp\ipykernel_15204\1195939285.py:21: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_json = pd.read_json(re.sub(r"^```json\s*|\s*```$", "", response.text, flags=re.DOTALL))
# 50
# Should Derivatives Be Privileged in Bankruptcy?
# Regulatory Arbitrage and Cross-Border Bank Acquisitions
# Risk Overhang and Loan Portfolio Decisions: Smarter Banks, Riskier Loans?
# Is Historical Cost Accounting a Panacea? Market Reactions to Accounting Rule Changes
#
# Internal Capital Markets in Business Groups: Evidence from China
# Foreclosures, House Prices, and the Real Economy
# Asset Quality Misrepresentation by Financial Intermediaries
# The People in Your Neighborhood: Social Interactions and Fund Manager Behavior
# Mandatory Portfolio Disclosure, Stock Liquidity, and Price Informativeness
# Government Intervention and Information Aggregation
# CEO Preferences and Acquisitions
# The Wall Street Walk when Blockholders Compete
# Reaching for Yield in the Bond Market
# Arbitrage Asymmetry and the Idiosyncratic Volatility Puzzle
# Wall Street Occupations
# Market Making Contracts, Firm Value, and the Impact of Regulation
# Asymmetric Learning from Financial Information
# Informational Frictions and Commodity Markets
# The Beauty Contest and Short-Term Trading
# CEO Turnover and Relative Performance Evaluation
# The Cost of Capital for Alternative Investments
# Hidden Liquidity: Some New Light on Dark Trading
# Outsourcing in the International Mutual Fund Industry
# The Role of Institutional Investors in Voting: Evidence from Shareholder Meetings
# Presidential Address: Does Finance Benefit Society?
# Does Going Public Affect Innovation?
# The Value of Control and the Costs of Illiquidity
# The Impact of Incentives and Communication Costs on Corporate Decisions
# A Model of Mortgage Default
# Do Prices Reveal the Presence of Informed Traders?
# Investment Decisions of Nonprofit Firms: Evidence from the Field
# The Brain Gain of Corporate Boards: Evidence from Director Networks
# A Comparative-Advantage Approach to Government Debt Maturity
# Information Diversity and Complementarities in Teams
# Capital and Labor Reallocation within Firms
# Transparency in the Financial System: Rollover Risk and Market Freezes
# Rewarding Trading Skills without Inducing Gambling
# Change You Can Believe In? Hedge Fund Data Reveals Reliability Issues
# Innovation, Growth, and Asset Prices
# Anchoring on Credit Spreads
# Is a VC Partnership Greater Than the Sum of Its Parts?
# Dividend Dynamics and the Term Structure of Dividends
# The Effect of Providing Peer Information on Retirement Savings
# CEO Connectedness and Corporate Fraud
# The WACC Fallacy: The Real Effects of Using a Flawed Cost of Capital
# Corporate Taxes and Securitization
# How Does Household Portfolio Diversification Vary Across the Globe?
# Subsidizing Liquidity: The Impact of Make/Take Fees on Trading
# Incentivizing Calculated Risk-Taking: Evidence from a Field Experiment
# Aggregate Jump and Volatility Risk in the Cross-Section of Stock Returns
# batch50
# C:\Users\Lab\AppData\Local\Temp\ipykernel_15204\1195939285.py:21: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_json = pd.read_json(re.sub(r"^```json\s*|\s*```$", "", response.text, flags=re.DOTALL))
# 50
# Should Derivatives Be Privileged in Bankruptcy?
# Regulatory Arbitrage and Cross-Border Bank Acquisitions
# Risk Overhang and Loan Portfolio Decisions: Smarter Banks, Riskier Loans?
# Is Historical Cost Accounting a Panacea? Market Reactions to Accounting Rule Changes
#
# Internal Capital Markets in Business Groups: Evidence from China
# Foreclosures, House Prices, and the Real Economy
# Asset Quality Misrepresentation by Financial Intermediaries
# The People in Your Neighborhood: Social Interactions and Fund Manager Behavior
# Mandatory Portfolio Disclosure, Stock Liquidity, and Price Informativeness
# Government Intervention and Information Aggregation
# CEO Preferences and Acquisitions
# The Wall Street Walk when Blockholders Compete
# Reaching for Yield in the Bond Market
# Arbitrage Asymmetry and the Idiosyncratic Volatility Puzzle
# Wall Street Occupations
# Market Making Contracts, Firm Value, and the Impact of Regulation
# Asymmetric Learning from Financial Information
# Informational Frictions and Commodity Markets
# The Beauty Contest and Short-Term Trading
# CEO Turnover and Relative Performance Evaluation
# The Cost of Capital for Alternative Investments
# Hidden Liquidity: Some New Light on Dark Trading
# Outsourcing in the International Mutual Fund Industry
# The Role of Institutional Investors in Voting: Evidence from Shareholder Meetings
# Presidential Address: Does Finance Benefit Society?
# Does Going Public Affect Innovation?
# The Value of Control and the Costs of Illiquidity
# The Impact of Incentives and Communication Costs on Corporate Decisions
# A Model of Mortgage Default
# Do Prices Reveal the Presence of Informed Traders?
# Investment Decisions of Nonprofit Firms: Evidence from the Field
# The Brain Gain of Corporate Boards: Evidence from Director Networks
# A Comparative-Advantage Approach to Government Debt Maturity
# Information Diversity and Complementarities in Teams
# Capital and Labor Reallocation within Firms
# Transparency in the Financial System: Rollover Risk and Market Freezes
# Rewarding Trading Skills without Inducing Gambling
# Change You Can Believe In? Hedge Fund Data Reveals Reliability Issues
# Innovation, Growth, and Asset Prices
# Anchoring on Credit Spreads
# Is a VC Partnership Greater Than the Sum of Its Parts?
# Dividend Dynamics and the Term Structure of Dividends
# The Effect of Providing Peer Information on Retirement Savings
# CEO Connectedness and Corporate Fraud
# The WACC Fallacy: The Real Effects of Using a Flawed Cost of Capital
# Corporate Taxes and Securitization
# How Does Household Portfolio Diversification Vary Across the Globe?
# Subsidizing Liquidity: The Impact of Make/Take Fees on Trading
# Incentivizing Calculated Risk-Taking: Evidence from a Field Experiment
# Aggregate Jump and Volatility Risk in the Cross-Section of Stock Returns
# The Recovery Theorem
# The Effect of Succession Taxes on Family Firm...
# Subprime Mortgage Defaults and Credit Default...
# Size Anomalies in U.S. Bank Stock Returns
# Estimating Oil Risk Factors Using Information...
# Defined Contribution Pension Plans: Sticky or...
# Yesterday's Heroes: Compensation and Risk at F...
# On the Design of Contingent Capital with a Mar...
# A Crisis of Banks as Liquidity Providers
# Taxes and Corporate Policies: Evidence from a ...
# Money Doctors
# Inflation Risk in Corporate Bonds
# Urban Vibrancy and Corporate Growth
# Short-Term Debt as Bridge Financing: Evidence ...
# Taking the Long Way Home: U.S. Tax Evasion and...
# Do Acquisitions Relieve Target Firms’ Financia...
# The Pre-FOMC Announcement Drift
# How Stable Are Corporate Capital Structures?
# Click or Call? Auction versus Search in the Ov...
# Borrower Misreporting and Loan Performance
# Misspecified Recovery
# Do Creditor Rights Increase Employment Risk? E...
# Corporate Scandals and Household Stock Market ...
# Credit Rationing, Income Exaggeration, and Adv...
# A Tale of Two Runs: Depositor Responses to Ban...
# “Lucas” in the Laboratory
# Compensating Financial Experts
# Learning about Mutual Fund Managers
# Valuation Risk and Asset Pricing
# Behind the Scenes: The Corporate Governance Pr...
# Ties That Bind: How Business Connections Affec...
# Infrequent Rebalancing, Return Autocorrelation...
# Who Borrows from the Lender of Last Resort?
# Trade Credit and Industry Dynamics: Evidence f...
# Financing Constraints and Workplace Safety
# Capital Investment, Innovative Capacity, and S...
# Speculative Betas
# Why Invest in Emerging Markets? The Role of Co...
# Can Brokers Have It All? On the Relation betwe...
# Firing Costs and Capital Structure Decisions
# Boom and Gloom
# Picking Winners? Investment Consultants’ Recom...
# Advertising Expensive Mortgages
# The Price of Political Uncertainty: Theory and...
# Presidential Address: Debt and Money: Financia...
# A Model of Financialization of Commodities
# Return Seasonalities
# The Impact of Venture Capital Monitoring
# On Enhancing Shareholder Control: A (Dodd-Fr...
# Risk-Sharing or Risk-Taking? Counterparty Risk...
# batch100
# C:\Users\Lab\AppData\Local\Temp\ipykernel_15204\1195939285.py:21: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_json = pd.read_json(re.sub(r"^```json\s*|\s*```$", "", response.text, flags=re.DOTALL))
# 50
# Should Derivatives Be Privileged in Bankruptcy?
# Regulatory Arbitrage and Cross-Border Bank Acquisitions
# Risk Overhang and Loan Portfolio Decisions: Smarter Banks, Riskier Loans?
# Is Historical Cost Accounting a Panacea? Market Reactions to Accounting Rule Changes
#
# Internal Capital Markets in Business Groups: Evidence from China
# Foreclosures, House Prices, and the Real Economy
# Asset Quality Misrepresentation by Financial Intermediaries
# The People in Your Neighborhood: Social Interactions and Fund Manager Behavior
# Mandatory Portfolio Disclosure, Stock Liquidity, and Price Informativeness
# Government Intervention and Information Aggregation
# CEO Preferences and Acquisitions
# The Wall Street Walk when Blockholders Compete
# Reaching for Yield in the Bond Market
# Arbitrage Asymmetry and the Idiosyncratic Volatility Puzzle
# Wall Street Occupations
# Market Making Contracts, Firm Value, and the Impact of Regulation
# Asymmetric Learning from Financial Information
# Informational Frictions and Commodity Markets
# The Beauty Contest and Short-Term Trading
# CEO Turnover and Relative Performance Evaluation
# The Cost of Capital for Alternative Investments
# Hidden Liquidity: Some New Light on Dark Trading
# Outsourcing in the International Mutual Fund Industry
# The Role of Institutional Investors in Voting: Evidence from Shareholder Meetings
# Presidential Address: Does Finance Benefit Society?
# Does Going Public Affect Innovation?
# The Value of Control and the Costs of Illiquidity
# The Impact of Incentives and Communication Costs on Corporate Decisions
# A Model of Mortgage Default
# Do Prices Reveal the Presence of Informed Traders?
# Investment Decisions of Nonprofit Firms: Evidence from the Field
# The Brain Gain of Corporate Boards: Evidence from Director Networks
# A Comparative-Advantage Approach to Government Debt Maturity
# Information Diversity and Complementarities in Teams
# Capital and Labor Reallocation within Firms
# Transparency in the Financial System: Rollover Risk and Market Freezes
# Rewarding Trading Skills without Inducing Gambling
# Change You Can Believe In? Hedge Fund Data Reveals Reliability Issues
# Innovation, Growth, and Asset Prices
# Anchoring on Credit Spreads
# Is a VC Partnership Greater Than the Sum of Its Parts?
# Dividend Dynamics and the Term Structure of Dividends
# The Effect of Providing Peer Information on Retirement Savings
# CEO Connectedness and Corporate Fraud
# The WACC Fallacy: The Real Effects of Using a Flawed Cost of Capital
# Corporate Taxes and Securitization
# How Does Household Portfolio Diversification Vary Across the Globe?
# Subsidizing Liquidity: The Impact of Make/Take Fees on Trading
# Incentivizing Calculated Risk-Taking: Evidence from a Field Experiment
# Aggregate Jump and Volatility Risk in the Cross-Section of Stock Returns
# The Recovery Theorem
# The Effect of Succession Taxes on Family Firm...
# Subprime Mortgage Defaults and Credit Default...
# Size Anomalies in U.S. Bank Stock Returns
# Estimating Oil Risk Factors Using Information...
# Defined Contribution Pension Plans: Sticky or...
# Yesterday's Heroes: Compensation and Risk at F...
# On the Design of Contingent Capital with a Mar...
# A Crisis of Banks as Liquidity Providers
# Taxes and Corporate Policies: Evidence from a ...
# Money Doctors
# Inflation Risk in Corporate Bonds
# Urban Vibrancy and Corporate Growth
# Short-Term Debt as Bridge Financing: Evidence ...
# Taking the Long Way Home: U.S. Tax Evasion and...
# Do Acquisitions Relieve Target Firms’ Financia...
# The Pre-FOMC Announcement Drift
# How Stable Are Corporate Capital Structures?
# Click or Call? Auction versus Search in the Ov...
# Borrower Misreporting and Loan Performance
# Misspecified Recovery
# Do Creditor Rights Increase Employment Risk? E...
# Corporate Scandals and Household Stock Market ...
# Credit Rationing, Income Exaggeration, and Adv...
# A Tale of Two Runs: Depositor Responses to Ban...
# “Lucas” in the Laboratory
# Compensating Financial Experts
# Learning about Mutual Fund Managers
# Valuation Risk and Asset Pricing
# Behind the Scenes: The Corporate Governance Pr...
# Ties That Bind: How Business Connections Affec...
# Infrequent Rebalancing, Return Autocorrelation...
# Who Borrows from the Lender of Last Resort?
# Trade Credit and Industry Dynamics: Evidence f...
# Financing Constraints and Workplace Safety
# Capital Investment, Innovative Capacity, and S...
# Speculative Betas
# Why Invest in Emerging Markets? The Role of Co...
# Can Brokers Have It All? On the Relation betwe...
# Firing Costs and Capital Structure Decisions
# Boom and Gloom
# Picking Winners? Investment Consultants’ Recom...
# Advertising Expensive Mortgages
# The Price of Political Uncertainty: Theory and...
# Presidential Address: Debt and Money: Financia...
# A Model of Financialization of Commodities
# Return Seasonalities
# The Impact of Venture Capital Monitoring
# On Enhancing Shareholder Control: A (Dodd-Fr...
# Risk-Sharing or Risk-Taking? Counterparty Risk...
# Good-Specific Habit Formation and the Cross-Section of Stock Returns
# Do Private Firms Invest Differently than Public Firms?
# It Pays to Set the Menu: Mutual Fund Investment Decisions and Performance
# Exodus from Sovereign Risk: Global Asset and Investment Flows
# The Optimal Size of Hedge Funds: Conflict between Investors and Managers
# Local Currency Sovereign Risk
# Asymmetric Information about Collateral Values
# Information Acquisition in Rumor-Based Bank Runs
# Exporting Liquidity: Branch Banking and Financial Markets
# The Boats That Did Not Sail: Asset Price Volatility and Information
# Worrying about the Stock Market: Evidence from Patient Records
# Short Selling and Earnings Management: A Contrasting Relationship
# Collateralization, Bank Loan Rates, and Monitoring
# From Wall Street to Main Street: The Impact of the Asset-Backed Securities Market Collapse
# The Total Cost of Corporate Borrowing in the Loan Market
# Information in the Term Structure of Yield Curves
# Risk-Adjusting the Returns to Venture Capital
# Boarding a Sinking Ship? An Investigation of Joint Liability and Managerial Incentives
# Learning about Consumption Dynamics
# Information Flows in Foreign Exchange Markets: Evidence from Order Flow
# Conglomerate Investment, Skewness, and the CEO's Risk Preferences
# Order Flow and Expected Option Returns
# Cream-Skimming in Financial Markets
# Does It Pay to Bet Against Beta? On the Conditional Relationship between Beta and Returns
# The Labor Market for Directors and Externalities
# An Information-Based Theory of Time-Varying Liquidity
# Indirect Incentives of Hedge Fund Managers
# Procyclical Capital Regulation and Lending
# Health and Mortality Delta: Assessing the Welfare Effects of Risk Measures
# Does Academic Research Destroy Stock Return Predictability?
# Stock Market Volatility and Learning
# Earnings Announcements and Systematic Risk
# Corporate Acquisitions, Diversification, and the CEO's Career Concerns
# Disappearing Call Delay and Dividend-Protected Bonds
# The Calm before the Storm
# Looking for Someone to Blame: Delegation, Cognition, and Financial Markets
# Can Markets Discipline Government Agencies? Evidence from Financial Markets
# News Trading and Speed
# Mutual Fund Flows and Cross-Fund Learning with Performance Evaluation
# Idiosyncratic Cash Flows and Systematic Risk
# The Determinants of Long-Term Corporate Debt Issuance
# The Macroeconomics of Shadow Banking
# Consumer Ruthlessness and Mortgage Default during the 2007-2009 Financial Crisis
# Matching Capital and Labor
# Why Do Investors Hold Socially Responsible Mutual Funds?
# How Do Quasi-Random Option Grants Affect CEO Behavior?
# Are CDS Auctions Biased and Inefficient?
# Commodity Trade and the Carry Trade: A Tale of Two Markets
# Financial Transaction Taxes, Market Composition, and Liquidity
# Why Does Return Predictability Concentrate in Certain Periods?
# batch150
# C:\Users\Lab\AppData\Local\Temp\ipykernel_15204\1195939285.py:21: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_json = pd.read_json(re.sub(r"^```json\s*|\s*```$", "", response.text, flags=re.DOTALL))
# 50
# Should Derivatives Be Privileged in Bankruptcy?
# Regulatory Arbitrage and Cross-Border Bank Acquisitions
# Risk Overhang and Loan Portfolio Decisions: Smarter Banks, Riskier Loans?
# Is Historical Cost Accounting a Panacea? Market Reactions to Accounting Rule Changes
#
# Internal Capital Markets in Business Groups: Evidence from China
# Foreclosures, House Prices, and the Real Economy
# Asset Quality Misrepresentation by Financial Intermediaries
# The People in Your Neighborhood: Social Interactions and Fund Manager Behavior
# Mandatory Portfolio Disclosure, Stock Liquidity, and Price Informativeness
# Government Intervention and Information Aggregation
# CEO Preferences and Acquisitions
# The Wall Street Walk when Blockholders Compete
# Reaching for Yield in the Bond Market
# Arbitrage Asymmetry and the Idiosyncratic Volatility Puzzle
# Wall Street Occupations
# Market Making Contracts, Firm Value, and the Impact of Regulation
# Asymmetric Learning from Financial Information
# Informational Frictions and Commodity Markets
# The Beauty Contest and Short-Term Trading
# CEO Turnover and Relative Performance Evaluation
# The Cost of Capital for Alternative Investments
# Hidden Liquidity: Some New Light on Dark Trading
# Outsourcing in the International Mutual Fund Industry
# The Role of Institutional Investors in Voting: Evidence from Shareholder Meetings
# Presidential Address: Does Finance Benefit Society?
# Does Going Public Affect Innovation?
# The Value of Control and the Costs of Illiquidity
# The Impact of Incentives and Communication Costs on Corporate Decisions
# A Model of Mortgage Default
# Do Prices Reveal the Presence of Informed Traders?
# Investment Decisions of Nonprofit Firms: Evidence from the Field
# The Brain Gain of Corporate Boards: Evidence from Director Networks
# A Comparative-Advantage Approach to Government Debt Maturity
# Information Diversity and Complementarities in Teams
# Capital and Labor Reallocation within Firms
# Transparency in the Financial System: Rollover Risk and Market Freezes
# Rewarding Trading Skills without Inducing Gambling
# Change You Can Believe In? Hedge Fund Data Reveals Reliability Issues
# Innovation, Growth, and Asset Prices
# Anchoring on Credit Spreads
# Is a VC Partnership Greater Than the Sum of Its Parts?
# Dividend Dynamics and the Term Structure of Dividends
# The Effect of Providing Peer Information on Retirement Savings
# CEO Connectedness and Corporate Fraud
# The WACC Fallacy: The Real Effects of Using a Flawed Cost of Capital
# Corporate Taxes and Securitization
# How Does Household Portfolio Diversification Vary Across the Globe?
# Subsidizing Liquidity: The Impact of Make/Take Fees on Trading
# Incentivizing Calculated Risk-Taking: Evidence from a Field Experiment
# Aggregate Jump and Volatility Risk in the Cross-Section of Stock Returns
# The Recovery Theorem
# The Effect of Succession Taxes on Family Firm...
# Subprime Mortgage Defaults and Credit Default...
# Size Anomalies in U.S. Bank Stock Returns
# Estimating Oil Risk Factors Using Information...
# Defined Contribution Pension Plans: Sticky or...
# Yesterday's Heroes: Compensation and Risk at F...
# On the Design of Contingent Capital with a Mar...
# A Crisis of Banks as Liquidity Providers
# Taxes and Corporate Policies: Evidence from a ...
# Money Doctors
# Inflation Risk in Corporate Bonds
# Urban Vibrancy and Corporate Growth
# Short-Term Debt as Bridge Financing: Evidence ...
# Taking the Long Way Home: U.S. Tax Evasion and...
# Do Acquisitions Relieve Target Firms’ Financia...
# The Pre-FOMC Announcement Drift
# How Stable Are Corporate Capital Structures?
# Click or Call? Auction versus Search in the Ov...
# Borrower Misreporting and Loan Performance
# Misspecified Recovery
# Do Creditor Rights Increase Employment Risk? E...
# Corporate Scandals and Household Stock Market ...
# Credit Rationing, Income Exaggeration, and Adv...
# A Tale of Two Runs: Depositor Responses to Ban...
# “Lucas” in the Laboratory
# Compensating Financial Experts
# Learning about Mutual Fund Managers
# Valuation Risk and Asset Pricing
# Behind the Scenes: The Corporate Governance Pr...
# Ties That Bind: How Business Connections Affec...
# Infrequent Rebalancing, Return Autocorrelation...
# Who Borrows from the Lender of Last Resort?
# Trade Credit and Industry Dynamics: Evidence f...
# Financing Constraints and Workplace Safety
# Capital Investment, Innovative Capacity, and S...
# Speculative Betas
# Why Invest in Emerging Markets? The Role of Co...
# Can Brokers Have It All? On the Relation betwe...
# Firing Costs and Capital Structure Decisions
# Boom and Gloom
# Picking Winners? Investment Consultants’ Recom...
# Advertising Expensive Mortgages
# The Price of Political Uncertainty: Theory and...
# Presidential Address: Debt and Money: Financia...
# A Model of Financialization of Commodities
# Return Seasonalities
# The Impact of Venture Capital Monitoring
# On Enhancing Shareholder Control: A (Dodd-Fr...
# Risk-Sharing or Risk-Taking? Counterparty Risk...
# Good-Specific Habit Formation and the Cross-Section of Stock Returns
# Do Private Firms Invest Differently than Public Firms?
# It Pays to Set the Menu: Mutual Fund Investment Decisions and Performance
# Exodus from Sovereign Risk: Global Asset and Investment Flows
# The Optimal Size of Hedge Funds: Conflict between Investors and Managers
# Local Currency Sovereign Risk
# Asymmetric Information about Collateral Values
# Information Acquisition in Rumor-Based Bank Runs
# Exporting Liquidity: Branch Banking and Financial Markets
# The Boats That Did Not Sail: Asset Price Volatility and Information
# Worrying about the Stock Market: Evidence from Patient Records
# Short Selling and Earnings Management: A Contrasting Relationship
# Collateralization, Bank Loan Rates, and Monitoring
# From Wall Street to Main Street: The Impact of the Asset-Backed Securities Market Collapse
# The Total Cost of Corporate Borrowing in the Loan Market
# Information in the Term Structure of Yield Curves
# Risk-Adjusting the Returns to Venture Capital
# Boarding a Sinking Ship? An Investigation of Joint Liability and Managerial Incentives
# Learning about Consumption Dynamics
# Information Flows in Foreign Exchange Markets: Evidence from Order Flow
# Conglomerate Investment, Skewness, and the CEO's Risk Preferences
# Order Flow and Expected Option Returns
# Cream-Skimming in Financial Markets
# Does It Pay to Bet Against Beta? On the Conditional Relationship between Beta and Returns
# The Labor Market for Directors and Externalities
# An Information-Based Theory of Time-Varying Liquidity
# Indirect Incentives of Hedge Fund Managers
# Procyclical Capital Regulation and Lending
# Health and Mortality Delta: Assessing the Welfare Effects of Risk Measures
# Does Academic Research Destroy Stock Return Predictability?
# Stock Market Volatility and Learning
# Earnings Announcements and Systematic Risk
# Corporate Acquisitions, Diversification, and the CEO's Career Concerns
# Disappearing Call Delay and Dividend-Protected Bonds
# The Calm before the Storm
# Looking for Someone to Blame: Delegation, Cognition, and Financial Markets
# Can Markets Discipline Government Agencies? Evidence from Financial Markets
# News Trading and Speed
# Mutual Fund Flows and Cross-Fund Learning with Performance Evaluation
# Idiosyncratic Cash Flows and Systematic Risk
# The Determinants of Long-Term Corporate Debt Issuance
# The Macroeconomics of Shadow Banking
# Consumer Ruthlessness and Mortgage Default during the 2007-2009 Financial Crisis
# Matching Capital and Labor
# Why Do Investors Hold Socially Responsible Mutual Funds?
# How Do Quasi-Random Option Grants Affect CEO Behavior?
# Are CDS Auctions Biased and Inefficient?
# Commodity Trade and the Carry Trade: A Tale of Two Markets
# Financial Transaction Taxes, Market Composition, and Liquidity
# Why Does Return Predictability Concentrate in Certain Periods?
# Nonfundamental Speculation Revisited
# The Front Men of Wall Street: The Role of CDO Managers
# The Downside of Asset Screening for Market Liquidity
# Benchmarks in Search Markets
# What Drives the Cross-Section of Credit Spread?
# Income Insurance and the Equilibrium Term Structure of Interest Rates
# A Labor-Search-Based Asset Pricing Model
# Firm Investment and Stakeholder Choices: A Top-Down Model
# On the Origins of Risk-Taking in Financial Markets
# Do Cash Flows of Growth Stocks Really Grow Faster?
# Consumer Default, Credit Reporting, and Borrowing Costs
# Presidential Address: The Scientific Outlook in Finance
# Retail Financial Advice: Does One Size Fit All?
# Do Funds Make More When They Trade More?
# Term Structure of Consumption Risk Premia in the Cross-Section of Asset Returns
# Trader Leverage and Liquidity
# Volatility-Managed Portfolios
# Advance Refundings of Municipal Bonds
# Municipal Bond Liquidity and Default Risk
# Selling Failed Banks
# Social Capital, Trust, and Firm Performance: The Role of Networks
# Capital Account Liberalization and Aggregate Private Consumption
# The Flash Crash: High-Frequency Trading in an Illiquid Market
# Firm Age, Investment Opportunities, and Job Creation
# Finance and Growth at the Firm Level: Evidence from SBA Loans
# Forced Asset Sales and the Concentration of Output
# Liquidity in a Market for Unique Assets: Specificity and Collateral
# The Effect of Housing on Portfolio Choice
# Exchange Rates and Monetary Policy Uncertainty
# Correlated Default and Financial Intermediation
# Does the Scope of the Sell-Side Analyst Industry Matter?
# Short-Term Market Risks Implied by Weekly Options
# Attracting Early-Stage Investors: Evidence from a Randomized Field Experiment
# Politically Connected Private Equity and Employment
# Mortgage Debt Overhang: Reduced Investment by Homeowners at Risk of Default
# Bank Leverage and Monetary Policy's Risk-Taking Channel
# Linear-Rational Term Structure Models
# Asset Market Participation and Portfolio Choice
# Before an Analyst Becomes an Analyst: Does Industry Experience Matter?
# Precautionary Savings with Risky Assets: When Does It Pay Off?
# On the Foundations of Corporate Social Responsibility
# Reverse Mortgage Loans: A Quantitative Analysis
# Who Are the Value and Growth Investors?
# Asset Pricing without Garbage
# Housing Collateral and Entrepreneurship
# Formative Experiences and Portfolio Choice: Evidence from a Natural Experiment
# What Doesn't Kill You Will Only Make You More Resilient: Managerial Style and Firm Performance
# Resident Networks and Corporate Connections: Evidence from Port Authority Data
# The Real Effects of Credit Ratings: The Sovereign Debt Channel
# Financial Contracting and Organizational Form: Evidence from Private Firms
# batch200
# C:\Users\Lab\AppData\Local\Temp\ipykernel_15204\1195939285.py:21: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_json = pd.read_json(re.sub(r"^```json\s*|\s*```$", "", response.text, flags=re.DOTALL))
# 50
# Should Derivatives Be Privileged in Bankruptcy?
# Regulatory Arbitrage and Cross-Border Bank Acquisitions
# Risk Overhang and Loan Portfolio Decisions: Smarter Banks, Riskier Loans?
# Is Historical Cost Accounting a Panacea? Market Reactions to Accounting Rule Changes
#
# Internal Capital Markets in Business Groups: Evidence from China
# Foreclosures, House Prices, and the Real Economy
# Asset Quality Misrepresentation by Financial Intermediaries
# The People in Your Neighborhood: Social Interactions and Fund Manager Behavior
# Mandatory Portfolio Disclosure, Stock Liquidity, and Price Informativeness
# Government Intervention and Information Aggregation
# CEO Preferences and Acquisitions
# The Wall Street Walk when Blockholders Compete
# Reaching for Yield in the Bond Market
# Arbitrage Asymmetry and the Idiosyncratic Volatility Puzzle
# Wall Street Occupations
# Market Making Contracts, Firm Value, and the Impact of Regulation
# Asymmetric Learning from Financial Information
# Informational Frictions and Commodity Markets
# The Beauty Contest and Short-Term Trading
# CEO Turnover and Relative Performance Evaluation
# The Cost of Capital for Alternative Investments
# Hidden Liquidity: Some New Light on Dark Trading
# Outsourcing in the International Mutual Fund Industry
# The Role of Institutional Investors in Voting: Evidence from Shareholder Meetings
# Presidential Address: Does Finance Benefit Society?
# Does Going Public Affect Innovation?
# The Value of Control and the Costs of Illiquidity
# The Impact of Incentives and Communication Costs on Corporate Decisions
# A Model of Mortgage Default
# Do Prices Reveal the Presence of Informed Traders?
# Investment Decisions of Nonprofit Firms: Evidence from the Field
# The Brain Gain of Corporate Boards: Evidence from Director Networks
# A Comparative-Advantage Approach to Government Debt Maturity
# Information Diversity and Complementarities in Teams
# Capital and Labor Reallocation within Firms
# Transparency in the Financial System: Rollover Risk and Market Freezes
# Rewarding Trading Skills without Inducing Gambling
# Change You Can Believe In? Hedge Fund Data Reveals Reliability Issues
# Innovation, Growth, and Asset Prices
# Anchoring on Credit Spreads
# Is a VC Partnership Greater Than the Sum of Its Parts?
# Dividend Dynamics and the Term Structure of Dividends
# The Effect of Providing Peer Information on Retirement Savings
# CEO Connectedness and Corporate Fraud
# The WACC Fallacy: The Real Effects of Using a Flawed Cost of Capital
# Corporate Taxes and Securitization
# How Does Household Portfolio Diversification Vary Across the Globe?
# Subsidizing Liquidity: The Impact of Make/Take Fees on Trading
# Incentivizing Calculated Risk-Taking: Evidence from a Field Experiment
# Aggregate Jump and Volatility Risk in the Cross-Section of Stock Returns
# The Recovery Theorem
# The Effect of Succession Taxes on Family Firm...
# Subprime Mortgage Defaults and Credit Default...
# Size Anomalies in U.S. Bank Stock Returns
# Estimating Oil Risk Factors Using Information...
# Defined Contribution Pension Plans: Sticky or...
# Yesterday's Heroes: Compensation and Risk at F...
# On the Design of Contingent Capital with a Mar...
# A Crisis of Banks as Liquidity Providers
# Taxes and Corporate Policies: Evidence from a ...
# Money Doctors
# Inflation Risk in Corporate Bonds
# Urban Vibrancy and Corporate Growth
# Short-Term Debt as Bridge Financing: Evidence ...
# Taking the Long Way Home: U.S. Tax Evasion and...
# Do Acquisitions Relieve Target Firms’ Financia...
# The Pre-FOMC Announcement Drift
# How Stable Are Corporate Capital Structures?
# Click or Call? Auction versus Search in the Ov...
# Borrower Misreporting and Loan Performance
# Misspecified Recovery
# Do Creditor Rights Increase Employment Risk? E...
# Corporate Scandals and Household Stock Market ...
# Credit Rationing, Income Exaggeration, and Adv...
# A Tale of Two Runs: Depositor Responses to Ban...
# “Lucas” in the Laboratory
# Compensating Financial Experts
# Learning about Mutual Fund Managers
# Valuation Risk and Asset Pricing
# Behind the Scenes: The Corporate Governance Pr...
# Ties That Bind: How Business Connections Affec...
# Infrequent Rebalancing, Return Autocorrelation...
# Who Borrows from the Lender of Last Resort?
# Trade Credit and Industry Dynamics: Evidence f...
# Financing Constraints and Workplace Safety
# Capital Investment, Innovative Capacity, and S...
# Speculative Betas
# Why Invest in Emerging Markets? The Role of Co...
# Can Brokers Have It All? On the Relation betwe...
# Firing Costs and Capital Structure Decisions
# Boom and Gloom
# Picking Winners? Investment Consultants’ Recom...
# Advertising Expensive Mortgages
# The Price of Political Uncertainty: Theory and...
# Presidential Address: Debt and Money: Financia...
# A Model of Financialization of Commodities
# Return Seasonalities
# The Impact of Venture Capital Monitoring
# On Enhancing Shareholder Control: A (Dodd-Fr...
# Risk-Sharing or Risk-Taking? Counterparty Risk...
# Good-Specific Habit Formation and the Cross-Section of Stock Returns
# Do Private Firms Invest Differently than Public Firms?
# It Pays to Set the Menu: Mutual Fund Investment Decisions and Performance
# Exodus from Sovereign Risk: Global Asset and Investment Flows
# The Optimal Size of Hedge Funds: Conflict between Investors and Managers
# Local Currency Sovereign Risk
# Asymmetric Information about Collateral Values
# Information Acquisition in Rumor-Based Bank Runs
# Exporting Liquidity: Branch Banking and Financial Markets
# The Boats That Did Not Sail: Asset Price Volatility and Information
# Worrying about the Stock Market: Evidence from Patient Records
# Short Selling and Earnings Management: A Contrasting Relationship
# Collateralization, Bank Loan Rates, and Monitoring
# From Wall Street to Main Street: The Impact of the Asset-Backed Securities Market Collapse
# The Total Cost of Corporate Borrowing in the Loan Market
# Information in the Term Structure of Yield Curves
# Risk-Adjusting the Returns to Venture Capital
# Boarding a Sinking Ship? An Investigation of Joint Liability and Managerial Incentives
# Learning about Consumption Dynamics
# Information Flows in Foreign Exchange Markets: Evidence from Order Flow
# Conglomerate Investment, Skewness, and the CEO's Risk Preferences
# Order Flow and Expected Option Returns
# Cream-Skimming in Financial Markets
# Does It Pay to Bet Against Beta? On the Conditional Relationship between Beta and Returns
# The Labor Market for Directors and Externalities
# An Information-Based Theory of Time-Varying Liquidity
# Indirect Incentives of Hedge Fund Managers
# Procyclical Capital Regulation and Lending
# Health and Mortality Delta: Assessing the Welfare Effects of Risk Measures
# Does Academic Research Destroy Stock Return Predictability?
# Stock Market Volatility and Learning
# Earnings Announcements and Systematic Risk
# Corporate Acquisitions, Diversification, and the CEO's Career Concerns
# Disappearing Call Delay and Dividend-Protected Bonds
# The Calm before the Storm
# Looking for Someone to Blame: Delegation, Cognition, and Financial Markets
# Can Markets Discipline Government Agencies? Evidence from Financial Markets
# News Trading and Speed
# Mutual Fund Flows and Cross-Fund Learning with Performance Evaluation
# Idiosyncratic Cash Flows and Systematic Risk
# The Determinants of Long-Term Corporate Debt Issuance
# The Macroeconomics of Shadow Banking
# Consumer Ruthlessness and Mortgage Default during the 2007-2009 Financial Crisis
# Matching Capital and Labor
# Why Do Investors Hold Socially Responsible Mutual Funds?
# How Do Quasi-Random Option Grants Affect CEO Behavior?
# Are CDS Auctions Biased and Inefficient?
# Commodity Trade and the Carry Trade: A Tale of Two Markets
# Financial Transaction Taxes, Market Composition, and Liquidity
# Why Does Return Predictability Concentrate in Certain Periods?
# Nonfundamental Speculation Revisited
# The Front Men of Wall Street: The Role of CDO Managers
# The Downside of Asset Screening for Market Liquidity
# Benchmarks in Search Markets
# What Drives the Cross-Section of Credit Spread?
# Income Insurance and the Equilibrium Term Structure of Interest Rates
# A Labor-Search-Based Asset Pricing Model
# Firm Investment and Stakeholder Choices: A Top-Down Model
# On the Origins of Risk-Taking in Financial Markets
# Do Cash Flows of Growth Stocks Really Grow Faster?
# Consumer Default, Credit Reporting, and Borrowing Costs
# Presidential Address: The Scientific Outlook in Finance
# Retail Financial Advice: Does One Size Fit All?
# Do Funds Make More When They Trade More?
# Term Structure of Consumption Risk Premia in the Cross-Section of Asset Returns
# Trader Leverage and Liquidity
# Volatility-Managed Portfolios
# Advance Refundings of Municipal Bonds
# Municipal Bond Liquidity and Default Risk
# Selling Failed Banks
# Social Capital, Trust, and Firm Performance: The Role of Networks
# Capital Account Liberalization and Aggregate Private Consumption
# The Flash Crash: High-Frequency Trading in an Illiquid Market
# Firm Age, Investment Opportunities, and Job Creation
# Finance and Growth at the Firm Level: Evidence from SBA Loans
# Forced Asset Sales and the Concentration of Output
# Liquidity in a Market for Unique Assets: Specificity and Collateral
# The Effect of Housing on Portfolio Choice
# Exchange Rates and Monetary Policy Uncertainty
# Correlated Default and Financial Intermediation
# Does the Scope of the Sell-Side Analyst Industry Matter?
# Short-Term Market Risks Implied by Weekly Options
# Attracting Early-Stage Investors: Evidence from a Randomized Field Experiment
# Politically Connected Private Equity and Employment
# Mortgage Debt Overhang: Reduced Investment by Homeowners at Risk of Default
# Bank Leverage and Monetary Policy's Risk-Taking Channel
# Linear-Rational Term Structure Models
# Asset Market Participation and Portfolio Choice
# Before an Analyst Becomes an Analyst: Does Industry Experience Matter?
# Precautionary Savings with Risky Assets: When Does It Pay Off?
# On the Foundations of Corporate Social Responsibility
# Reverse Mortgage Loans: A Quantitative Analysis
# Who Are the Value and Growth Investors?
# Asset Pricing without Garbage
# Housing Collateral and Entrepreneurship
# Formative Experiences and Portfolio Choice: Evidence from a Natural Experiment
# What Doesn't Kill You Will Only Make You More Resilient: Managerial Style and Firm Performance
# Resident Networks and Corporate Connections: Evidence from Port Authority Data
# The Real Effects of Credit Ratings: The Sovereign Debt Channel
# Financial Contracting and Organizational Form: Evidence from Private Firms
# Buyout Activity: The Impact of Aggregate Discounting on Firm Value
# Asset Pricing with Countercyclical Household Consumption
# Local Risk, Local Factors, and Asset Prices
# Ex-Dividend Profitability and Institutional Trading
# Do ETFs Increase Volatility?
# Unscheduled News and Market Dynamics
# Arrested Development: Theory and Evidence of Sticky Prices
# Influencing Control: Jawboning in Risk Arbitrage
# The Politics of Foreclosures
# Currency Risk Factors in a Recursive Multicountry Model
# Collateral Constraints and the Law of One Price
# The Impact of Bank Credit on Labor Reallocation
# Noncognitive Abilities and Financial Delinquency
# Sensation Seeking and Hedge Funds
# Anomalies and News
# Can Innovation Help U.S. Manufacturing Firms Escape the "Middle Income Trap"?
# Political Representation and Governance: Evidence from Pension Funds
# The Geography of Financial Misconduct
# Expected Inflation and Other Determinants of Term Premia
# Asset Management within Commercial Banking Groups
# Does Herding Behavior Reveal Skill? An Analysis of Mutual Fund Managers
# Rankings and Risk-Taking in the Finance Industry
# Quid Pro Quo? What Factors Influence IPO Allocations?
# Do Rare Events Explain CDX Tranche Spreads?
# Creditor Control Rights and Board Independence
# CMBS and Conflicts of Interest: Evidence from Related-Party Transactions
# Presidential Address: Pension Policy and the Financial Crisis
# Anticompetitive Effects of Common Ownership
# A Tough Act to Follow: Contrast Effects in Financial Markets
# Capital Commitment and Illiquidity in Corporate Debt
# Efficiently Inefficient Markets for Assets and Derivatives
# The Dynamics of Financially Constrained Arbitrage
# Estimating Private Equity Returns from Limited Partnership Data
# Networks in Production: Asset Pricing Implications
# Can Taxes Shape an Industry? Evidence from the Online Retail Sector
# An Experimental Study of Bond Market Pricing
# On the Asset Allocation of a Default Pension Fund
# Deviations from Covered Interest Rate Parity
# Is Sell-Side Research More Valuable in Bad Times?
# The Fed, the Bond Market, and Gradualism in Monetary Policy
# Higher Order Effects in Asset Pricing Models
# What Makes a Good Trader? On the Role of Intuition
# How Do Financing Constraints Affect Firms' Equity Issuance?
# Interpreting Factor Models
# Belief Dispersion in the Stock Market
# Margin Requirements and the Security Market Line
# Is Proprietary Trading Detrimental to Retail Investors?
# Real Options Models of the Firm, Capacity Overhang, and Investment
# Is Fraud Contagious? Coworker Influence on Misconduct
# Unshrouding: Evidence from Bank Overdrafts
# batch250
# C:\Users\Lab\AppData\Local\Temp\ipykernel_15204\1195939285.py:21: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_json = pd.read_json(re.sub(r"^```json\s*|\s*```$", "", response.text, flags=re.DOTALL))
# 50
# Should Derivatives Be Privileged in Bankruptcy?
# Regulatory Arbitrage and Cross-Border Bank Acquisitions
# Risk Overhang and Loan Portfolio Decisions: Smarter Banks, Riskier Loans?
# Is Historical Cost Accounting a Panacea? Market Reactions to Accounting Rule Changes
#
# Internal Capital Markets in Business Groups: Evidence from China
# Foreclosures, House Prices, and the Real Economy
# Asset Quality Misrepresentation by Financial Intermediaries
# The People in Your Neighborhood: Social Interactions and Fund Manager Behavior
# Mandatory Portfolio Disclosure, Stock Liquidity, and Price Informativeness
# Government Intervention and Information Aggregation
# CEO Preferences and Acquisitions
# The Wall Street Walk when Blockholders Compete
# Reaching for Yield in the Bond Market
# Arbitrage Asymmetry and the Idiosyncratic Volatility Puzzle
# Wall Street Occupations
# Market Making Contracts, Firm Value, and the Impact of Regulation
# Asymmetric Learning from Financial Information
# Informational Frictions and Commodity Markets
# The Beauty Contest and Short-Term Trading
# CEO Turnover and Relative Performance Evaluation
# The Cost of Capital for Alternative Investments
# Hidden Liquidity: Some New Light on Dark Trading
# Outsourcing in the International Mutual Fund Industry
# The Role of Institutional Investors in Voting: Evidence from Shareholder Meetings
# Presidential Address: Does Finance Benefit Society?
# Does Going Public Affect Innovation?
# The Value of Control and the Costs of Illiquidity
# The Impact of Incentives and Communication Costs on Corporate Decisions
# A Model of Mortgage Default
# Do Prices Reveal the Presence of Informed Traders?
# Investment Decisions of Nonprofit Firms: Evidence from the Field
# The Brain Gain of Corporate Boards: Evidence from Director Networks
# A Comparative-Advantage Approach to Government Debt Maturity
# Information Diversity and Complementarities in Teams
# Capital and Labor Reallocation within Firms
# Transparency in the Financial System: Rollover Risk and Market Freezes
# Rewarding Trading Skills without Inducing Gambling
# Change You Can Believe In? Hedge Fund Data Reveals Reliability Issues
# Innovation, Growth, and Asset Prices
# Anchoring on Credit Spreads
# Is a VC Partnership Greater Than the Sum of Its Parts?
# Dividend Dynamics and the Term Structure of Dividends
# The Effect of Providing Peer Information on Retirement Savings
# CEO Connectedness and Corporate Fraud
# The WACC Fallacy: The Real Effects of Using a Flawed Cost of Capital
# Corporate Taxes and Securitization
# How Does Household Portfolio Diversification Vary Across the Globe?
# Subsidizing Liquidity: The Impact of Make/Take Fees on Trading
# Incentivizing Calculated Risk-Taking: Evidence from a Field Experiment
# Aggregate Jump and Volatility Risk in the Cross-Section of Stock Returns
# The Recovery Theorem
# The Effect of Succession Taxes on Family Firm...
# Subprime Mortgage Defaults and Credit Default...
# Size Anomalies in U.S. Bank Stock Returns
# Estimating Oil Risk Factors Using Information...
# Defined Contribution Pension Plans: Sticky or...
# Yesterday's Heroes: Compensation and Risk at F...
# On the Design of Contingent Capital with a Mar...
# A Crisis of Banks as Liquidity Providers
# Taxes and Corporate Policies: Evidence from a ...
# Money Doctors
# Inflation Risk in Corporate Bonds
# Urban Vibrancy and Corporate Growth
# Short-Term Debt as Bridge Financing: Evidence ...
# Taking the Long Way Home: U.S. Tax Evasion and...
# Do Acquisitions Relieve Target Firms’ Financia...
# The Pre-FOMC Announcement Drift
# How Stable Are Corporate Capital Structures?
# Click or Call? Auction versus Search in the Ov...
# Borrower Misreporting and Loan Performance
# Misspecified Recovery
# Do Creditor Rights Increase Employment Risk? E...
# Corporate Scandals and Household Stock Market ...
# Credit Rationing, Income Exaggeration, and Adv...
# A Tale of Two Runs: Depositor Responses to Ban...
# “Lucas” in the Laboratory
# Compensating Financial Experts
# Learning about Mutual Fund Managers
# Valuation Risk and Asset Pricing
# Behind the Scenes: The Corporate Governance Pr...
# Ties That Bind: How Business Connections Affec...
# Infrequent Rebalancing, Return Autocorrelation...
# Who Borrows from the Lender of Last Resort?
# Trade Credit and Industry Dynamics: Evidence f...
# Financing Constraints and Workplace Safety
# Capital Investment, Innovative Capacity, and S...
# Speculative Betas
# Why Invest in Emerging Markets? The Role of Co...
# Can Brokers Have It All? On the Relation betwe...
# Firing Costs and Capital Structure Decisions
# Boom and Gloom
# Picking Winners? Investment Consultants’ Recom...
# Advertising Expensive Mortgages
# The Price of Political Uncertainty: Theory and...
# Presidential Address: Debt and Money: Financia...
# A Model of Financialization of Commodities
# Return Seasonalities
# The Impact of Venture Capital Monitoring
# On Enhancing Shareholder Control: A (Dodd-Fr...
# Risk-Sharing or Risk-Taking? Counterparty Risk...
# Good-Specific Habit Formation and the Cross-Section of Stock Returns
# Do Private Firms Invest Differently than Public Firms?
# It Pays to Set the Menu: Mutual Fund Investment Decisions and Performance
# Exodus from Sovereign Risk: Global Asset and Investment Flows
# The Optimal Size of Hedge Funds: Conflict between Investors and Managers
# Local Currency Sovereign Risk
# Asymmetric Information about Collateral Values
# Information Acquisition in Rumor-Based Bank Runs
# Exporting Liquidity: Branch Banking and Financial Markets
# The Boats That Did Not Sail: Asset Price Volatility and Information
# Worrying about the Stock Market: Evidence from Patient Records
# Short Selling and Earnings Management: A Contrasting Relationship
# Collateralization, Bank Loan Rates, and Monitoring
# From Wall Street to Main Street: The Impact of the Asset-Backed Securities Market Collapse
# The Total Cost of Corporate Borrowing in the Loan Market
# Information in the Term Structure of Yield Curves
# Risk-Adjusting the Returns to Venture Capital
# Boarding a Sinking Ship? An Investigation of Joint Liability and Managerial Incentives
# Learning about Consumption Dynamics
# Information Flows in Foreign Exchange Markets: Evidence from Order Flow
# Conglomerate Investment, Skewness, and the CEO's Risk Preferences
# Order Flow and Expected Option Returns
# Cream-Skimming in Financial Markets
# Does It Pay to Bet Against Beta? On the Conditional Relationship between Beta and Returns
# The Labor Market for Directors and Externalities
# An Information-Based Theory of Time-Varying Liquidity
# Indirect Incentives of Hedge Fund Managers
# Procyclical Capital Regulation and Lending
# Health and Mortality Delta: Assessing the Welfare Effects of Risk Measures
# Does Academic Research Destroy Stock Return Predictability?
# Stock Market Volatility and Learning
# Earnings Announcements and Systematic Risk
# Corporate Acquisitions, Diversification, and the CEO's Career Concerns
# Disappearing Call Delay and Dividend-Protected Bonds
# The Calm before the Storm
# Looking for Someone to Blame: Delegation, Cognition, and Financial Markets
# Can Markets Discipline Government Agencies? Evidence from Financial Markets
# News Trading and Speed
# Mutual Fund Flows and Cross-Fund Learning with Performance Evaluation
# Idiosyncratic Cash Flows and Systematic Risk
# The Determinants of Long-Term Corporate Debt Issuance
# The Macroeconomics of Shadow Banking
# Consumer Ruthlessness and Mortgage Default during the 2007-2009 Financial Crisis
# Matching Capital and Labor
# ...
# Structuring Mortgages for Macroeconomic Stability
# Out-of-Town Home Buyers and City Welfare
# Prospect Theory and Stock Market Anomalies
# Risk Management in Financial Institutions: A Review
# Presidential Address: How Much 'Rationality' Is There in Finance?
# What Explains Differences in Finance Research?
# Don't Take Their Word for It: The Misclassification of Bond Fund Managers
# Weathering Cash Flow Shocks
# Are CEOs Different?
# A Theory of Zombie Lending
# Rent Extraction with Securities Plus Cash
# How Debit Cards Enable the Poor to Save More
# Time Variation of the Equity Term Structure
# Sentiment Trading and Hedge Fund Returns
# Asset Managers: Institutional Performance and ...
# Foreign Safe Asset Demand and the Dollar Excha...
# Banking on Deposits: Maturity Transformation w...
# Monetary Policy and Reaching for Income
# Leverage Dynamics without Commitment
# Fire-Sale Spillovers and Systemic Risk
# Leveraged Funds and the Shadow Cost of Leverag...
# Subjective Cash Flow and Discount Rate Expecta...
# Who Wears the Pants? Gender Identity Norms and...
# The Economics of Hedge Fund Startups: Theory a...
# Trading Costs and Informational Efficiency
# For Richer, for Poorer: Bankers' Liability and...
# The Private Production of Safe Assets
# Mutual Fund Holdings of Credit Default Swaps: ...
# The Misguided Beliefs of Financial Advisors
# The Impact of Repossession Risk on Mortgage De...
# Financial Fragility with SAM?
# Anonymous Trading in Equities
# Liquidity Supply in the Corporate Bond Market
# The Perception of Dependence, Investment Decis...
# Public Thrift, Private Perks: Signaling Board ...
# Limited Risk Sharing and International Equity ...
# Model-Free International Stochastic Discount F...
# Equilibrium Asset Pricing with Leverage and De...
# The Limits of Limited Liability: Evidence from...
# Do Household Wealth Shocks Affect Productivity...
# Mortgage Design in an Equilibrium Model of the...
# The Capitalization of Consumer Financing into ...
# Inalienable Customer Capital, Corporate Liquid...
# A Dynamic Model of Optimal Creditor Dispersion
# A Unified Model of Firm Dynamics with Limited ...
# Information Consumption and Asset Pricing
# Learning From Disagreement in the U.S. Treasur...
# Information Inertia
# Loan Terms and Collateral: Evidence from the B...
# Import Competition and Household Debt
# The Two-Pillar Policy for the RMB
# Attention-Induced Trading and Returns: Evidenc...
# Belief Disagreement and Portfolio Choice
# Asset Pricing with Cohort-Based Trading in MBS...
# The Price of Higher Order Catastrophe Insuranc...
# Financial Crises and Political Radicalization:...
# Stock Market Spillovers via the Global Product...
# The Anatomy of the Transmission of Macropruden...
# The Cost of Capital for Banks: Evidence from A...
# Commodity Financialization and Information Tra...
# When Should Bankruptcy Law Be Creditor- or Deb...
# Rare Disasters, Financial Development, and Sovereign Debt
# Common Ownership Does Not Have Anticompetitive Effects
# Rising Intangible Capital, Shrinking Debt Capacity
# A Theory of Equivalent Expectation Measures for Asset Pricing
# The Golden Mean: The Risk-Mitigating Effect of Diversification
# CEO Political Leanings and Store-Level Economic Outcomes
# Presidential Address: Corporate Finance and Regulation
# Do Firms Respond to Gender Pay Gap Transparency?
# Bank Market Power and Monetary Policy Transmission
# Quantifying Reduced-Form Evidence on Collateral Constraints
# A New Test of Risk Factor Relevance
# Testing Disagreement Models
# Debt Refinancing and Equity Returns
# Risk-Sharing and the Term Structure of Interest Rates
# Stock Market's Assessment of Monetary Policy Transmission
# The Economics of Deferral and Clawback Requirements
# Financial Crisis, Creditor-Debtor Conflict, and Asset Prices
# Barbarians at the Store? Private Equity, Production, and Prices
# The Wisdom of the Robinhood Crowd
# Fully Closed: Individual Responses to Realized Gains and Losses
# Long-Run Risk: Is It There?
# The Limits of Model-Based Regulation
# Resource Allocation in Bank Supervision: Trade-offs and Efficiency
# Learning by Owning in a Lemons Market
# Is There a Risk Premium in the Stock Lending Market?
# Are Analyst Short-Term Trade Ideas Valuable?
# Factor Momentum and the Momentum Factor
# Luck versus Skill in the Cross Section of Mutual Fund Returns
# The Fragility of Market Risk Insurance
# Predictable Financial Crises
# Late to Recessions: Stocks and the Business Cycle
# Monetary Policy and Asset Valuation
# Payment System Externalities
# Volatility Expectations and Returns
# Dissecting Conglomerate Valuations
# Common Risk Factors in Cryptocurrency
# Do Market Prices Improve the Accuracy of Court Decisions?
# Regulation of Charlatans in High-Skill Professions
# Going the Extra Mile: Distant Lending and Creditor Rights
# Liquidity Fluctuations in Over-the-Counter Markets
# Do Equity Markets Care about Income Inequality?
# Cultural Biases in Equity Analysis
# Selling Fast and Buying Slow: Heuristics and Trading Behavior
# Informational Black Holes in Financial Markets
# Option Momentum
# (Re-)Imag(in)ing Price Trends
# Household Liquidity Constraints and Labor Market Outcomes
# Booms, Busts, and Common Risk Exposures
# Entrepreneurial Wealth and Employment: Tracing the Link
# Operating Hedge and Gross Profitability Premium
# The Legal Origins of Financial Development: Evidence from the Roman Empire
# Retail Trading in Options and the Rise of the Retail Investor
# Attention Spillover in Asset Pricing
# Discount Rates, Debt Maturity, and the Fiscal Theory of the Price Level
# Optimal Forbearance of Bank Resolution
# Global Pricing of Carbon-Transition Risk
# Moral Hazard versus Liquidity in Household Banking
# Is There a Replication Crisis in Finance?
# Complex Asset Markets
# Pledgeability and Asset Prices: Evidence from the Art Market
# Investor Tax Credits and Entrepreneurship: Evidence from the Art Market
# Retail Financial Innovation and Stock Market Development
# Contracting in Peer Networks
# Dynamic Contracting with Intermediation: Operations and Equilibrium
# Stealth Acquisitions and Product Market Competition
# Do Credit Markets Respond to Macroeconomic Shocks?
# Monetary Policy and Inequality
# (Why) Do Central Banks Care about Their Profits?
# Presidential Address: Sustainable Finance and the Future of Finance
# Rents and Intangible Capital: A Q+ Framework
# Can Security Design Foster Household Risk-Taking?
# Modeling Corporate Bond Returns
# Barter Credit: Warehouses as a Contracting Technology
# Specialization in Bank Lending: Evidence from the Loan Market
# Employee Costs of Corporate Bankruptcy
# Optimal Sequential Selling Mechanism and Deal Design
# Liquidity, Volume, and Order Imbalance Volatility
# Is COVID Revealing a Virus in CMBS 2.0?
# Competition and Misconduct
# Reusing Natural Experiments
# Retail Derivatives and Sentiment: A Sentiment Analysis
# CLO Performance
# Pockets of Predictability
# The Pollution Premium
# Duration-Driven Returns
# Firm-Level Climate Change Exposure
# Macroeconomic News in Asset Pricing and Reality
# Who Owns What? A Factor Model for Direct Stock Holdings
# Integrating Factor Models
# Visibility Bias in the Transmission of Consumption
# Naïve Buying Diversification and Narrow Framing
# Model Comparison with Transaction Costs
# Did FinTech Lenders Facilitate PPP Fraud?
# Pricing Currency Risks
# A Model of Systemic Bank Runs
# Biased Auctioneers
# Discount-Rate Risk in Private Equity: Evidence from Buyouts
# Do Municipal Bond Dealers Give Their Customers the Best Prices?
# Information Aggregation via Contracting
# Equilibrium Bitcoin Pricing
# Local Experiences, Search, and Spillovers in the Housing Market
# Model Secrecy and Stress Tests
# The Gender Gap in Housing Returns
# Monetary Stimulus amidst the Infrastructure Investment Boom
# Optimal Financial Transaction Taxes
# Less Mainstream Credit, More Payday Borrowing?
# Disruption and Credit Markets
# How Risky Are U.S. Corporate Assets?
# International Yield Curves and Currency Puzzles
# Decentralization through Tokenization
# Beyond Basis Basics: Liquidity Demand and Deviations from the Law of One Price
# Principal Portfolios
# Small Business Equity Returns: Empirical Evidence
# Beliefs Aggregation and Return Predictability
# Bayesian Solutions for the Factor Zoo: We Just Need One
# Presidential Address: Macrofinance and Resilience
# Mortgage Lock-In, Mobility, and Labor Reallocation
# Financial Sophistication and Consumer Spending
# Time-Consistent Individuals, Time-Inconsistent Preferences, and Consumption
# A Multifactor Perspective on Volatility-Managed Portfolios
# Bonds versus Equities: Information for Investment
# Putting the Price in Asset Pricing
# Liquidity Transformation and Fragility in the Banking Sector
# Currency Management by International Fixed-Income Investors
# Treasury Bill Shortages and the Pricing of Short-Term Debt
# Equity Term Structures without Dividend Strips
# Utility Tokens as a Commitment to Competition
# The Working Capital Credit Multiplier
# Lying to Speak the Truth: Selective Manipulation in Principal-Agent Models
# Did Banks Pay Fair Returns to Taxpayers on TARP?
# Liquidity, Liquidity Everywhere, Not a Drop to Drink
# Bailout Stigma
# The SOE Premium and Government Support in China
# Business News and Business Cycles
# The Mortgage-Cash Premium Puzzle
# Unobserved Performance of Hedge Funds
# Do Women Receive Worse Financial Advice?
# FinTech Credit and Entrepreneurial Growth
# Founder-CEO Compensation and Selection into Venture Capital
# Capital Commitment
# The Portfolio-Driven Disposition Effect
# Firm Performance Pay as Insurance against Promotion
# Anomaly Time
# Very Noisy Option Prices and Inference Regarding Volatility
# On the Magnification of Small Biases in Hiring
# A (Sub)penny for Your Thoughts: Tracking Retail Trades
# Spending Less after (Seemingly) Bad News
# Insensitive Investors
# Money and Banking with Reserves and CBDC
# The Time-Varying Price of Financial Intermediation
# What Drives Variation in the U.S. Debt-to-Outp...
# Inside and Outside Information
# Information Aggregation with Asymmetric Asset ...
# Half Banked: The Economic Impact of Cash Manag...
# Treasury Richness
# Meeting Targets in Competitive Product Markets
# Is Long-Run Risk Really Priced? Revisiting Liu...
# Monetary Policy and Asset Price Overshooting: ...
# Countercyclical Income Risk and Portfolio Choi...
# Tracing the International Transmission of a Cr...
# A Horizon-Based Decomposition of Mutual Fund V...
# Zombie Credit and (Dis-)Inflation: Evidence fr...
# Goal Setting and Saving in the FinTech Era
# Rent or Buy? Inflation Experiences and Homeown...
# A Portfolio Approach to Global Imbalances
# The Term Structure of Covered Interest Rate Pa...
# Due Diligence
# Broadband Internet and the Stock Market Invest...
# Mergers, Product Prices, and Innovation: Evide...
# Does Alternative Data Improve Financial Foreca...
# Modeling Conditional Factor Risk Premia Implie...
# Nonstandard Errors
# Political Polarization Affects Households' Fin...
# Measuring “Dark Matter” in Asset Pricing Models
# Informed Trading Intensity
# How Integrated are Credit and Equity Markets? ...
# Dissecting the Long-Term Performance of the Ch...
# The Narrow Channel of Quantitative Easing: Evi...
# Overconfidence and Preferences for Competition
# Disclosing a Random Walk
# A q Theory of Internal Capital Markets
# Fee Variation in Private Equity
# Aversion to Student Debt? Evidence from Low-Wa...
# The Equilibrium Size and Value-Added of Ventur...
# Auctions with Endogenous Initiation
# The Dark Side of Circuit Breakers
# Lender Automation and Racial Disparities in Cr...
# Disclosing to Informed Traders
# Leverage Is a Double-Edged Sword
# Choosing to Disagree: Endogenous Dismissivenes...
# Front-Page News: The Effect of News Positionin...
# The Decline of Secured Debt
# Liquidation Value and Loan Pricing
# Neglected Risks in the Communication of Reside...
# Interest Rate Skewness and Biased Beliefs
# Financing the Gig Economy
# Trading and Shareholder Democracy
# Legal Risk and Insider Trading
# Intervention with Screening in Panic-Based Runs
# The Global Impact of Brexit Uncertainty
# The Virtue of Complexity in Return Prediction
# Prestige, Promotion, and Pay
# Foreign Exchange Fixings and Returns around the Clock
# Information Cascades and Threshold Implementations
# Artificial Intelligence, Education, and Entrepreneurship
# Presidential Address: Housing Betas
# The Credit Line Channel
# The Imperfect Intermediation of Money-Like Assets
# The Stock Market and Bank Risk-Taking
# Going for Broke: Bank Reputation and the Performance of IPOs
# The Propagation of Cyberattacks through the Financial System
# Impediments to the Schumpeterian Process in the Digital Economy
# CEO Stress, Aging, and Death
# Privacy and Team Incentives
# ESG News, Future Cash Flows, and Firm Value
# Green Window Dressing
# War Discourse and the Cross Section of Expected Returns
# Anomalies and Their Short-Sale Costs
# Long-Horizon Exchange Rate Expectations
# Value without Employment
# Pockets of Predictability: A Replication
# Forest through the Trees: Building Cross-Sectional Asset Pricing Models
# The “Actual Retail Price” of Equity Trades
# Segmented Arbitrage
# Arbitrage Capital of Global Banks
# Persuading Investors: A Video-Based Study
# Does Saving Cause Borrowing? Implications for Household Portfolios
# Household Portfolios and Retirement Saving over the Life Cycle
# Investor Factors
# Over-the-Counter Markets for Nonstandardized Assets
# The Impact of the Financial Education of Executives on Firm Performance
# Too Much, Too Soon, for Too Long: The Dynamics of Executive Compensation
# Thirty Years of Change: The Evolution of Class Action Lawsuits
# Baby Booms and Asset Booms: Demographic Change and Financial Markets
# Superstar Returns? Spatial Heterogeneity in Real Estate Markets
# Would Order-By-Order Auctions Be Competitive?
# Regulating Over-the-Counter Markets
# Interlocking Directorates and Competition in Banking
# The Value of Bank Lending
# Dynamic Banking and the Value of Deposits
# What Is the Cost of Privatization for Workers?
# Venture Capital and Startup Agglomeration
# Women in Charge: Evidence from Hospitals
# Are CEOs Rewarded for Luck? Evidence from Corporate Tax Gains
# Creating Controversy in Proxy Voting Advice
# Is the United States a Lucky Survivor? A Hierarchical Approach
# The Term Structure of Interest Rates in a Heterogeneous Agent Model
# How Credit Cycles across a Financial Crisis
# Banks, Low Interest Rates, and Monetary Policy
# Collusion in Brokered Markets
# How Much Does Racial Bias Affect Mortgage Lending?
# Social Security and Trends in Wealth Inequality
# Excess Capacity, Marginal q, and Corporate Investment
# In Too Deep: The Effect of Sunk Costs on Corporate Investment
# Intrahousehold Disagreement about Macroeconomic Shocks
# In the Red: Overdrafts, Payday Lending, and the Cost of Credit
# Conflicting Priorities: A Theory of Covenants and Corporate Finance
# Auctions versus Negotiations: The Role of the Seller's Information
# Raising Capital from Investor Syndicates with Limited Liability
# The Disappearing Index Effect
# Sustainability or Greenwashing: Evidence from the Asset Market for Polluting Industries
# The Allocation of Socially Responsible Capital
# Pricing Poseidon: Extreme Weather Uncertainty and Firm-Level Uncertainty
# Designing Stress Scenarios
# Crisis Interventions in Corporate Insolvency
# Repo over the Financial Crisis
# Worker Runs
# Feedback Effects and Systematic Risk Exposures
# Simplicity and Risk
# Regulatory Fragmentation
# Wealth and Insurance Choices: Evidence from the U.S.
# Working More to Pay the Mortgage: Household Debt and Labor Supply
# The Impact of Minority Representation at Mortgage Lenders
# Uncovering the Hidden Effort Problem
# Bank Funding Risk, Reference Rates, and Credit Spreads
# Intermediary Leverage Shocks and Funding Conditions
# The Global Credit Spread Puzzle
# Private Equity and Financial Stability: Evidence from the U.S.
# Equilibrium Data Mining and Data Abundance
# Test Assets and Weak Factors
# Decentralized Exchange: The Uniswap Automated Market Maker
# Does Floor Trading Matter?
# Scope, Scale, and Concentration: The 21st-Century Firm
# Sending Out an SMS: Automatic Enrollment Experiments at Major U.S. Employers
# Personal Communication in an Automated World: Evidence from Text Message Marketing
# Dynamic Competition in Negotiated Price Markets
# Carbon Returns across the Globe

# %% [markdown]
# ### Tag validation

# %%
df_output = pd.DataFrame()
df_output = pd.concat([pd.read_csv("Journal of Accounting Research_response.csv"), pd.read_csv("Management Science_response.csv")], ignore_index=True)

# %%
response = client.models.generate_content(
    model='gemini-2.5-pro',
    config=GenerateContentConfig(
        system_instruction="Always respond *only* in valid JSON without extra commentary.", 
        temperature=0.8
    ),
    contents=
    f"""
    determine each of the strings in the following list is truly Artificial Intelligence related.  The  definition of Artificial Intelligence do not include broad computer science or fintech topics.  The output should be only in JSON format with two columns ['keyword_string', 'is_truly_AI'].
    """
    +
    str(list((df_output[df_output["is_AI_related"] == True])["AI_related_keyword"]))
)
print(response.text)
# Out:
# ```json
# [
#   {
#     "keyword_string": "LASSO",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Bitcoin",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "High-frequency trading",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "High-frequency trading",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "neural network",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "tokenization",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "utility tokens",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "natural language processing",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "FinTech",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "CBDC",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "alternative data",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "automation",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "text-based method",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Artificial Intelligence",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "text analysis",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "asset pricing models",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Automated Market Maker",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Robo-Advisors",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "digitalization, big data analytics, AI",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "data analytics",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "automated triage, machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "transactions data, data analytics",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "data science",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Industry 4.0 technologies",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Information technology",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "digital transformation",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "digital work instructions",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "reinforcement learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "digital manufacturing",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "automation, digital technology",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "digital transformation",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "digital supply chain",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "algorithms",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "blockchain",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "blockchain",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "blockchain, smart contracts",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "blockchain, tokenized operations",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "blockchain, tokenized operations",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "cyberattack",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "blockchain, misinformation",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "cyberattack, supply chain",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "analytics",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Textual Analysis",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "computational methods",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "computer vision techniques",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "fraud prediction model",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine learning, topic modeling",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "satellite imagery, computer vision, machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "big data, natural language processing, machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "information technology, AI, big data analytics",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Machine Learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Algorithmic Trading",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Machine Learning, Natural Language Processing",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "sequential learning, machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "learning algorithms, optimization, machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "automation, AI",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "automation, human-in-the-loop, AI",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "learning, continuous-time processes, machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine learning, financial reporting",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Machine Learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Causal Discovery",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Data Analytics",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Machine Learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine learning, predictive models",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "automated decision-making, AI, machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "choice model, machine learning, econometrics",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Artificial Intelligence, AI, audit firms, automation, data analytics",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine learning, alternative data, credit scoring, AI",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "automated system",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "autonomous vehicles",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "stochastic gradient descent",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "reinforcement learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Thompson sampling",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Markov decision processes",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "algorithms",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "approximate linear programs",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Multi-armed bandit",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "stochastic multi-armed bandit",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "online learning, personalized recommendations, autonomous driving",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Industry 4.0, predictive, three-dimensional printing",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Deep Learning, transition probability density",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Adwords, online advertising",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "online advertising, search models",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "AI analytics, innovation strategy",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "data analytics, personalized pricing",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "inventory policy learning, data-driven, newsvendor problem",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "search, e-commerce platforms, precision",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Machine Learning, demand estimation",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Learning Agents",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Online Learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Data-Driven",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Online Matching",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "artificial intelligence, machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "digital expert systems",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "online learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "learning algorithms",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Deep Learning, neural networks",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Large Language Model, AI",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Neural Network",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Predictive Analytics, machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "high-dimensional, regularized",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Automation",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Reinforcement Learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Automation",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "algorithms",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "RegTech",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "personalized revenue management",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Mean Field Games",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Matching Algorithms",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Bayesian Hierarchical Model",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Black Boxes, Algorithms",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Multiarmed Bandit",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "sentiment analysis",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "recommendation systems, algorithm",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "dynamic batch learning, machine learning, high-dimensional",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "reinforcement learning, dynamic treatment regimes",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "strategic behavior, decision making",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "structured multi-armed bandits",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "product recommendations",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Artificial Intelligence",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "textual analysis",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "policy learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Machines learn, machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Artificial Intelligence, AI agents, independent learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Machine Learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Machine Learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Machine Learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Optimization, Machine Learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Data-Driven, Optimization, Machine Learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Quantum Computing",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Technology",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Demand Learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Cryptocurrency",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Online Recruitment",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Optimization",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Blockchain",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Pricing",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Active Learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Reinforcement Learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Smart Contracts",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Cryptocurrency",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "learning algorithm",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "network analytics, privacy-preserving",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "stochastic optimization, random forests",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "recommender systems, AI",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Industrial Internet-of-Things",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "forecasting models",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "data-driven model",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Reinforcement Learning, Policy Gradient Methods",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "matchmaking algorithms",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "dynamic pricing, online reviews",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Contextual Bandits, Distributionally Robust",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Multi-armed bandit",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Technology, Financial",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "machine-learning, weather, climate",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine learning algorithms",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Deep Reinforcement Learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Generative AI",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "AI Systems",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "text mining",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "big models",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "transfer learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Machine Learning, Robo-advising",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Statistical Learning, Recommendation Systems",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Nonparametric modeling, Decision Forest",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Online Learning, Inventory Management",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Learning Algorithms, Hedging, Optimization",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Bayesian Learning, Sequential Learning, Clinical Trials",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "personalized pricing",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "support vector machine",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "predictive modeling",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "learning to rank",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine learning, sentiment analysis, natural language processing",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine learning, fairness, algorithmic bias",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "learning, optimization, demand forecasting",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "stochastic optimization, data pooling",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "pricing algorithms",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "model crowds",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "prediction",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "optimization",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "dimension reduction, supervised learning, PCA",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Algorithmic Fairness",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Machine Learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Machine Learning, Causal Inference",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Bayesian learning, empirical Bayes, machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "prescriptive analytics, optimization",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "conditional quantile prediction, robust optimization, machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "data-driven, approximation schemes, machine learning, inventory management, pricing",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "autonomous vehicles, last-mile delivery, logistics, optimization",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Explainable AI, clinical decision support, machine learning, healthcare",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "online learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "algorithmic recommendations",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "instrumental variable forest",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "meta-prediction",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "personalized pricing",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "data-driven approach",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "dynamic learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "reinforcement learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Data Science",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "data analytics",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "optimization",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "transfer learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "contextual bandits",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "text analysis",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "natural language processing",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Machine Learning, Fairness",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "robots, automation",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "personalized pricing, customer data",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "prediction algorithms",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "analytics",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "online learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "policy learning, reinforcement learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "algorithm",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "recommendation systems",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "reinforcement learning, recommendations",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "content-based model, information retrieval, natural language processing",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "algorithm",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "autonomous vehicle",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "cryptocurrency",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "online learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Stochastic Gradient Descent, Bandit Algorithms, Online Optimization",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "bias-variance trade-off",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "prescriptive analytics",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "bias-variance trade-off",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "automation",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "non-parametric estimation",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "information technology",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Monte Carlo integration",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "data-driven decision-making",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "data-driven",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "detection",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "data analytics",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "online communities",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "machine learning, personalization",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "learning algorithm, machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "clustering",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "optimization",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "prediction",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Markov decision processes",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine translation",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "inverse optimization",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "blockchain",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "random projection",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "modeling, consumer footprints, search engines",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "mobile targeting, customer trajectory patterns, location data",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Bayesian, ambiguity sets, distributional robust optimization",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "data-driven, patient scheduling, emergency departments, optimization",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "offshoring, return premium, text-based analysis, 10-K filings",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "multiperiod stock allocation, robust optimization, inventory management",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "algorithmic bias, recommendation systems",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "algorithmic trading",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "algorithmic pricing",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "algorithmic trading",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Data analytics",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Information Technology",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Automated forecasts, Machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Machine learning, Portfolio optimization",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "algorithm",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Big data analytics",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "Behavior-based advertising",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "Agent-based modeling",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "algorithms",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "algorithms",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "recommendation systems",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "machine learning, network analysis, fraud detection",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "algorithms, stochastic optimization, machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "algorithms, optimization, resource allocation",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "analytics, data analytics, optimization, machine learning",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "dynamic pricing, algorithms, optimization, real-time systems",
#     "is_truly_AI": false
#   },
#   {
#     "keyword_string": "multiarmed bandit",
#     "is_truly_AI": true
#   },
#   {
#     "keyword_string": "AI systems",
#     "is_truly_AI": true
#   }
# ]
# ```

# %%
df_validation = pd.read_json(re.sub(r"^```json\s*|\s*```$", "", response.text, flags=re.DOTALL))
# Out:
# C:\Users\Lab\AppData\Local\Temp\ipykernel_15204\3768903674.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_validation = pd.read_json(re.sub(r"^```json\s*|\s*```$", "", response.text, flags=re.DOTALL))

# %%
df_validation.drop_duplicates(subset="keyword_string", keep="first")
# Out:
#                                         keyword_string  is_truly_AI
# 0                                                LASSO        False
# 1                                              Bitcoin        False
# 2                               High-frequency trading        False
# 4                                       neural network         True
# 5                                         tokenization        False
# ..                                                 ...          ...
# 284      algorithms, optimization, resource allocation        False
# 285  analytics, data analytics, optimization, machi...         True
# 286  dynamic pricing, algorithms, optimization, rea...        False
# 287                                  multiarmed bandit         True
# 288                                         AI systems         True
#
# [232 rows x 2 columns]

# %%
df_output_validated = pd.merge(df_output, (df_validation.drop_duplicates(subset="keyword_string", keep="first")), left_on = "AI_related_keyword", right_on = "keyword_string", how = "left")

# %%
df_output_validated["is_truly_AI"] = df_output_validated["is_truly_AI"].fillna(False)
# Out:
# C:\Users\Lab\AppData\Local\Temp\ipykernel_15204\3334859555.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_output_validated["is_truly_AI"] = df_output_validated["is_truly_AI"].fillna(False)

# %%
df_output_validated.to_csv('journals_response_validated.csv', index=False)
